# %% [markdown]
# ### Import Dependencies

# %%
 from sklearn import tree
import pandas as pd
import os

# %% [markdown]
# ### Read in Data
# ### Happiness
# - 0 = Happy
# - 1 = Unhappy

# %%
df = pd.read_csv(os.path.join("..", "Data","Cleaned_Data","TVP_Happiness_Survey.csv"))
df.head()
# Out:
#    Sample  Access to Employment  Access to Public Transport  Culture  \
# 0       1                     8                           7        6
# 1       2                     1                           1        5
# 2       3                     9                           6        6
# 3       4                     4                           1        4
# 4       5                     9                          10        8
#
#    Road Congestion  Schools  Shopping  Open Space  Tree Cover  \
# 0               10        8         8           7           6
# 1                2        3         4           1           3
# 2                8        7         6           9           6
# 3                1        1         3           1           1
# 4               10       10         8           7           6
#
#    Topographic Variation  Cafes and Restaurants  Crime  Telecommunications  \
# 0                      7                      9      8                   8
# 1                      4                      4      4                   1
# 2                      9                      8      7                  10
# 3                      3                      2      1                   5
# 4                      8                      6      6                   8
#
#    Views  Beach Access  Happiness
# 0      8            10      Happy
# 1      4             2  Not Happy
# 2      9            10      Happy
# 3      3             2  Not Happy
# 4      8             6      Happy

# %%
target = df["Happiness"]
target_names = ["Happy", "Not Happy"]

# %%
data = df.drop("Happiness", axis=1)
data = data.drop("Sample", axis=1)
feature_names = data.columns
data.head()
# Out:
#    Access to Employment  Access to Public Transport  Culture  Road Congestion  \
# 0                     8                           7        6               10
# 1                     1                           1        5                2
# 2                     9                           6        6                8
# 3                     4                           1        4                1
# 4                     9                          10        8               10
#
#    Schools  Shopping  Open Space  Tree Cover  Topographic Variation  \
# 0        8         8           7           6                      7
# 1        3         4           1           3                      4
# 2        7         6           9           6                      9
# 3        1         3           1           1                      3
# 4       10         8           7           6                      8
#
#    Cafes and Restaurants  Crime  Telecommunications  Views  Beach Access
# 0                      9      8                   8      8            10
# 1                      4      4                   1      4             2
# 2                      8      7                  10      9            10
# 3                      2      1                   5      3             2
# 4                      6      6                   8      8             6

# %%
 from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data, target, random_state=42)

# %%
 clf = tree.DecisionTreeClassifier()
clf = clf.fit(X_train, y_train)
clf.score(X_test, y_test)
# Out:
# 1.0

# %%
 from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=50)
rf = rf.fit(X_train, y_train)
rf.score(X_test, y_test)
# Out:
# 1.0

# %%
sorted(zip(rf.feature_importances_, feature_names), reverse=True)
# Out:
# [(0.07372816912942104, 'Open Space'),
#  (0.07332976168259447, 'Access to Public Transport'),
#  (0.07245592783998321, 'Views'),
#  (0.07239868736592957, 'Topographic Variation'),
#  (0.07193082276505797, 'Culture'),
#  (0.07185300988745695, 'Tree Cover'),
#  (0.07184615754388692, 'Road Congestion'),
#  (0.07163372721597196, 'Cafes and Restaurants'),
#  (0.07089698518012265, 'Access to Employment'),
#  (0.0704623737308817, 'Beach Access'),
#  (0.07043442547512005, 'Schools'),
#  (0.07031072979346126, 'Telecommunications'),
#  (0.06945891961615402, 'Shopping'),
#  (0.06926030277395831, 'Crime')]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import os

# %%
Data_Happy = pd.read_csv(os.path.join("..", "Data","Cleaned_Data","TVP_Happiness_Survey.csv"))
Data_Happy.head()
# Out:
#    Sample  Access to Employment  Access to Public Transport  Culture  \
# 0       1                     8                           7        6
# 1       2                     1                           1        5
# 2       3                     9                           6        6
# 3       4                     4                           1        4
# 4       5                     9                          10        8
#
#    Road Congestion  Schools  Shopping  Open Space  Tree Cover  \
# 0               10        8         8           7           6
# 1                2        3         4           1           3
# 2                8        7         6           9           6
# 3                1        1         3           1           1
# 4               10       10         8           7           6
#
#    Topographic Variation  Cafes and Restaurants  Crime  Telecommunications  \
# 0                      7                      9      8                   8
# 1                      4                      4      4                   1
# 2                      9                      8      7                  10
# 3                      3                      2      1                   5
# 4                      8                      6      6                   8
#
#    Views  Beach Access  Happiness
# 0      8            10      Happy
# 1      4             2  Not Happy
# 2      9            10      Happy
# 3      3             2  Not Happy
# 4      8             6      Happy

# %%
# Assign X (data) and y (target)
X = Data_Happy.drop("Happiness", axis=1)
X = X.drop("Sample", axis=1)
y = Data_Happy["Happiness"]
print(X.shape, y.shape)
# Out:
# (3344, 14) (3344,)

# %%
 from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=23)

# %% [markdown]
# from sklearn.linear_model import LogisticRegression
# classifier = LogisticRegression()
# classifier

# %%
LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
          intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
          penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
          verbose=0, warm_start=False)
# Out:
# LogisticRegression(multi_class='ovr', n_jobs=1, solver='liblinear')

# %%
classifier.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
 LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
          intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
          penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
          verbose=0, warm_start=False)
# Out:
# LogisticRegression(multi_class='ovr', n_jobs=1, solver='liblinear')

# %%
print(f"Training Data Score: {classifier.score(X_train, y_train)}")
print(f"Testing Data Score: {classifier.score(X_test, y_test)}")
# Out:
# Training Data Score: 1.0
# Testing Data Score: 1.0

# %%
predictions = classifier.predict(X_test)
print(f"First 10 Predictions:   {predictions[:10]}")
print(f"First 10 Actual labels: {y_test[:10].tolist()}")
# Out:
# First 10 Predictions:   ['Happy' 'Not Happy' 'Happy' 'Not Happy' 'Not Happy' 'Not Happy' 'Happy'
#  'Happy' 'Happy' 'Happy']
# First 10 Actual labels: ['Not Happy', 'Not Happy', 'Not Happy', 'Not Happy', 'Happy', 'Not Happy', 'Not Happy', 'Not Happy', 'Not Happy', 'Not Happy']

# %%
 pd.DataFrame({"Prediction": predictions, "Actual": y_test}).reset_index(drop=True)
# Out:
#     Prediction     Actual
# 0        Happy  Not Happy
# 1    Not Happy  Not Happy
# 2        Happy  Not Happy
# 3    Not Happy  Not Happy
# 4    Not Happy      Happy
# ..         ...        ...
# 831  Not Happy  Not Happy
# 832      Happy  Not Happy
# 833  Not Happy  Not Happy
# 834      Happy  Not Happy
# 835  Not Happy  Not Happy
#
# [836 rows x 2 columns]
