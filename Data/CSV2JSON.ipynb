# %%
import pandas as pd
import json
file = "Cleaned_Data/ABS_TVP_Cleaned.csv"
datadf = pd.read_csv(file, encoding="ISO-8859-1")

# %%
datadf
# Out:
#       Code Prefix       Code                    Category          Variant  \
# 0             T01        T01                   Age & Sex              NaN
# 1             T01        T01                   Age & Sex              NaN
# 2             T01        T01                   Age & Sex              NaN
# 3             T01        T01                   Age & Sex              NaN
# 4             T01        T01                   Age & Sex              NaN
# ...           ...        ...                         ...              ...
# 43519         T25  T25-Total  Monthly Mortgage Repayment    $2,600-$2,999
# 43520         T25  T25-Total  Monthly Mortgage Repayment    $3,000-$3,999
# 43521         T25  T25-Total  Monthly Mortgage Repayment    $4,000-$4,999
# 43522         T25  T25-Total  Monthly Mortgage Repayment  $5,000 and over
# 43523         T25  T25-Total  Monthly Mortgage Repayment       Not stated
#
#            Sex       Age   2006   2011   2016
# 0        Males  All ages  13725  16307  17429
# 1      Females  All ages  14229  16127  17562
# 2      Persons  All ages  27959  32433  34990
# 3        Males         0    165    192    226
# 4      Females         0    173    221    234
# ...        ...       ...    ...    ...    ...
# 43519      NaN       NaN    101    389    393
# 43520      NaN       NaN    102    616    567
# 43521      NaN       NaN     28    206    203
# 43522      NaN       NaN     23    134    114
# 43523      NaN       NaN    212    136    118
#
# [43524 rows x 9 columns]

# %%
with open('data.json', 'w') as f:
    f.write(datadf.to_json(orient='records', lines=True))
